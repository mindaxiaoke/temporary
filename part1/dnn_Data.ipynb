# %%
# Using Train_X1:
#   spy(1:20) to predict spy(21)
# %run dnn_Data
# Out:
# start
# Training batches: 400
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 1.00317615646e-05', 'mean = 0.000109489847399')
# ('layer0', 'var = 0.365942950599', 'mean = 0.105958526508')
# ... training
# epoch 1, minibatch 400/400, validation error 7.854559 %
#      epoch 1, minibatch 400/400, test error of best model 5.431279 %
# epoch 2, minibatch 400/400, validation error 7.851758 %
#      epoch 2, minibatch 400/400, test error of best model 5.433685 %
# epoch 3, minibatch 400/400, validation error 7.851546 %
#      epoch 3, minibatch 400/400, test error of best model 5.433840 %
# epoch 4, minibatch 400/400, validation error 7.851491 %
#      epoch 4, minibatch 400/400, test error of best model 5.433807 %
# epoch 5, minibatch 400/400, validation error 7.851448 %
#      epoch 5, minibatch 400/400, test error of best model 5.433760 %
# epoch 6, minibatch 400/400, validation error 7.851405 %
# ...

# %%
# Using Train_X1:
#   spy(1:20) and signal(1:20) to predict spy(21)
# %run dnn_Data
# Out:
# start
# Training batches: 400
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 2.43298966481e-05', 'mean = 9.69519982459e-05')
# ('layer0', 'var = 0.390611286221', 'mean = -0.0332805337603')
# ... training
# epoch 1, minibatch 400/400, validation error 7.811218 %
#      epoch 1, minibatch 400/400, test error of best model 5.409761 %
# epoch 2, minibatch 400/400, validation error 7.806737 %
#      epoch 2, minibatch 400/400, test error of best model 5.412590 %
# epoch 3, minibatch 400/400, validation error 7.806214 %
#      epoch 3, minibatch 400/400, test error of best model 5.412886 %
# epoch 4, minibatch 400/400, validation error 7.806023 %
#      epoch 4, minibatch 400/400, test error of best model 5.412840 %
# epoch 5, minibatch 400/400, validation error 7.805867 %
#      epoch 5, minibatch 400/400, test error of best model 5.412757 %
# epoch 6, minibatch 400/400, validation error 7.805714 %
# ...
