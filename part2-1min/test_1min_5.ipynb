# %%
#learning_rate=0.0001, L1_reg=0.00, L2_reg=0.0001, n_epochs=50,
#             batch_size=20, n_hidden=50, n_hiddenLayers=1
# %run dnn_1minClassification.py
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.17465855699', 'mean = 0.0194242975056')
# ('layer0', 'var = 0.402027291133', 'mean = 0.0207455284589')
# ('layer0', 'var = 0.538576708223', 'mean = 0.0262449701045')
# ('layer0', 'var = 0.653058712069', 'mean = 0.0389236499027')
# ('layer0', 'var = 0.653000034591', 'mean = 0.0334005517542')
# ('layer0', 'var = 0.638016868238', 'mean = 0.0805415438944')
# ('layer0', 'var = 0.77899685119', 'mean = 0.0473961964494')
# ('layer0', 'var = 0.807632635804', 'mean = 0.0551313858312')
# ('layer0', 'var = 0.799073256318', 'mean = 0.058736302695')
# ('layer0', 'var = 0.897018111968', 'mean = 0.0222514542181')
# ('layer0', 'var = 0.909235951427', 'mean = -0.00268694853891')
# ('layer0', 'var = 0.902117079598', 'mean = 0.0210153553615')
# ('layer0', 'var = 0.91711628451', 'mean = 0.0353352009741')
# ('layer0', 'var = 0.892988831823', 'mean = 0.0536818193286')
# ...

# %%
#learning_rate=0.005, L1_reg=0.00, L2_reg=0.0001, n_epochs=50,
#             batch_size=20, n_hidden=50, n_hiddenLayers=1
# %run dnn_1minClassification.py
# save3
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.172380462793', 'mean = 0.0020267191867')
# ('layer0', 'var = 0.39659549656', 'mean = -0.0271086550396')
# ('layer0', 'var = 0.553873923268', 'mean = 0.0183375576')
# ('layer0', 'var = 0.641066769567', 'mean = -0.0320034532375')
# ('layer0', 'var = 0.663363382487', 'mean = -0.0511003610481')
# ('layer0', 'var = 0.6559211255', 'mean = -0.0138283157488')
# ('layer0', 'var = 0.75991358419', 'mean = -0.0243156879161')
# ('layer0', 'var = 0.81842074044', 'mean = -0.0184928401268')
# ('layer0', 'var = 0.808822357918', 'mean = -0.0673614394763')
# ('layer0', 'var = 0.86414216717', 'mean = 0.00639566436029')
# ('layer0', 'var = 0.895451319056', 'mean = -0.0187016145089')
# ('layer0', 'var = 0.903875924103', 'mean = 0.0345366407663')
# ('layer0', 'var = 0.931387964623', 'mean = -0.00896642057732')
# ('layer0', 'var = 0.892198055134', 'mean = -0.0115281070206')
# ...

# %%
#learning_rate=0.005, L1_reg=0.00, L2_reg=0.0001, n_epochs=50,
#             batch_size=20, n_hidden=100, n_hiddenLayers=1
# %run dnn_1minClassification.py
#save4
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.0998653885722', 'mean = -0.00255905875933')
# ('layer0', 'var = 0.379796779835', 'mean = 0.0116392951724')
# ('layer0', 'var = 0.529180686941', 'mean = 0.0150918160238')
# ('layer0', 'var = 0.639303817317', 'mean = 0.00456718109034')
# ('layer0', 'var = 0.647750759352', 'mean = 0.0193441948852')
# ('layer0', 'var = 0.642008063931', 'mean = 0.00787744746722')
# ('layer0', 'var = 0.755698696537', 'mean = 0.0134112658405')
# ('layer0', 'var = 0.803920997311', 'mean = 0.0207139521982')
# ('layer0', 'var = 0.820731116061', 'mean = 0.00890362307371')
# ('layer0', 'var = 0.868653618625', 'mean = 0.00125503356454')
# ('layer0', 'var = 0.89923446234', 'mean = 0.00754192633733')
# ('layer0', 'var = 0.897682472238', 'mean = 0.00307121289414')
# ('layer0', 'var = 0.916053671811', 'mean = 0.0318988842949')
# ('layer0', 'var = 0.894376349735', 'mean = 0.0197080801141')
# ...

# %%
#learning_rate=0.005, L1_reg=0.00, L2_reg=0.0001, n_epochs=50,
#             batch_size=20, n_hidden=100, n_hiddenLayers=2
# %run dnn_1minClassification.py
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.0999816586564', 'mean = 0.018955319202')
# ('layer0', 'var = 0.365797825521', 'mean = 0.0585792345952')
# ('layer0', 'var = 0.531811741133', 'mean = 0.0708656780502')
# ('layer0', 'var = 0.635372224155', 'mean = 0.0668230918605')
# ('layer0', 'var = 0.637372928819', 'mean = 0.095308082677')
# ('layer0', 'var = 0.647917115266', 'mean = 0.111815014376')
# ('layer0', 'var = 0.756640806506', 'mean = 0.0900073794074')
# ('layer0', 'var = 0.801786862155', 'mean = 0.0846930188739')
# ('layer0', 'var = 0.808181951887', 'mean = 0.0793985499581')
# ('layer0', 'var = 0.882670012024', 'mean = 0.0366681567507')
# ('layer0', 'var = 0.905003280647', 'mean = 0.0688428772755')
# ('layer0', 'var = 0.899451806537', 'mean = 0.0671453933903')
# ('layer0', 'var = 0.918715093318', 'mean = 0.0674519203118')
# ('layer0', 'var = 0.899295904136', 'mean = 0.0575425996718')
# ...

# %%
#learning_rate=0.005, L1_reg=0.00, L2_reg=0.0001, n_epochs=50,
#             batch_size=20, n_hidden=50, n_hiddenLayers=2
# %run dnn_1minClassification.py
#save5
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.17237694662', 'mean = 0.00894180235906')
# ('layer0', 'var = 0.409675384755', 'mean = 0.0215119639589')
# ('layer0', 'var = 0.531363418048', 'mean = 0.0126290662854')
# ('layer0', 'var = 0.644774287934', 'mean = 0.0421778572071')
# ('layer0', 'var = 0.662396358078', 'mean = 0.0270431115583')
# ('layer0', 'var = 0.644833305185', 'mean = 0.0413728839151')
# ('layer0', 'var = 0.766202210227', 'mean = 0.0472185535665')
# ('layer0', 'var = 0.822397271087', 'mean = 0.00595080558451')
# ('layer0', 'var = 0.812462300897', 'mean = 0.0370201145559')
# ('layer0', 'var = 0.871340061302', 'mean = 0.00232534526659')
# ('layer0', 'var = 0.913206125932', 'mean = 0.0348235787636')
# ('layer0', 'var = 0.905613856499', 'mean = 0.0129714040876')
# ('layer0', 'var = 0.926262635916', 'mean = -0.00374389482441')
# ('layer0', 'var = 0.906718299489', 'mean = 0.022039938222')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
#             batch_size=20, n_hidden=50, n_hiddenLayers=2
# %run dnn_1minClassification.py
#save5
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.168696211804', 'mean = 0.00741416165611')
# ('layer0', 'var = 0.40548727261', 'mean = 0.0209917873164')
# ('layer0', 'var = 0.559362020498', 'mean = 0.0320897705638')
# ('layer0', 'var = 0.651438109373', 'mean = 0.0153947339849')
# ('layer0', 'var = 0.638534466792', 'mean = 0.0267460788128')
# ('layer0', 'var = 0.649086262599', 'mean = -0.00333834308993')
# ('layer0', 'var = 0.77240588399', 'mean = -0.00406497341239')
# ('layer0', 'var = 0.80715212775', 'mean = 0.0335318188201')
# ('layer0', 'var = 0.819102545121', 'mean = 0.0389920935088')
# ('layer0', 'var = 0.885764286202', 'mean = 0.00500077507062')
# ('layer0', 'var = 0.897010594825', 'mean = -0.007788046083')
# ('layer0', 'var = 0.899118777978', 'mean = -0.000866616868588')
# ('layer0', 'var = 0.912864608389', 'mean = 0.0283104439103')
# ('layer0', 'var = 0.900954228154', 'mean = 0.040343786917')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
#             batch_size=20, n_hidden=50, n_hiddenLayers=3
# %run dnn_1minClassification.py
#save6
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.1733022016', 'mean = -0.0105198366425')
# ('layer0', 'var = 0.408967710148', 'mean = -0.026591208566')
# ('layer0', 'var = 0.557506600772', 'mean = -0.0252368077496')
# ('layer0', 'var = 0.638500124347', 'mean = -0.0398098060074')
# ('layer0', 'var = 0.657265571352', 'mean = -0.0235378354825')
# ('layer0', 'var = 0.638346420947', 'mean = -0.0387829556145')
# ('layer0', 'var = 0.753129990115', 'mean = -0.0450050920219')
# ('layer0', 'var = 0.805731463692', 'mean = -0.00784116035108')
# ('layer0', 'var = 0.811150115545', 'mean = -0.029637899945')
# ('layer0', 'var = 0.882481565337', 'mean = -0.042693729787')
# ('layer0', 'var = 0.896007116793', 'mean = -0.0769520946274')
# ('layer0', 'var = 0.912132488194', 'mean = -0.0341258262811')
# ('layer0', 'var = 0.919078181502', 'mean = -0.0282056096569')
# ('layer0', 'var = 0.886320146142', 'mean = -0.030881607278')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
#             batch_size=20, n_hidden=50, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save7
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.17234011148', 'mean = -0.022480260477')
# ('layer0', 'var = 0.404511607353', 'mean = -0.0195825000203')
# ('layer0', 'var = 0.545512747645', 'mean = -0.0456157375257')
# ('layer0', 'var = 0.652464433403', 'mean = -0.00704820814547')
# ('layer0', 'var = 0.652714227894', 'mean = -0.0136833581494')
# ('layer0', 'var = 0.643384865205', 'mean = -0.0244315218713')
# ('layer0', 'var = 0.770110111868', 'mean = -0.0100075187748')
# ('layer0', 'var = 0.820711050392', 'mean = -0.0252442614941')
# ('layer0', 'var = 0.819003228684', 'mean = -0.0066076886185')
# ('layer0', 'var = 0.881811994732', 'mean = -0.0352257734826')
# ('layer0', 'var = 0.912223974426', 'mean = -0.0305644576498')
# ('layer0', 'var = 0.906223727207', 'mean = -0.027401586452')
# ('layer0', 'var = 0.907341341829', 'mean = -0.0111745941697')
# ('layer0', 'var = 0.898853748719', 'mean = -0.0081396535576')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
#             batch_size=20, n_hidden=40, n_hiddenLayers=5
# %run dnn_1minClassification.py
#save8
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.206409523623', 'mean = 0.00637262796125')
# ('layer0', 'var = 0.412628865984', 'mean = 0.0111868003323')
# ('layer0', 'var = 0.548717982052', 'mean = 0.00565628291641')
# ('layer0', 'var = 0.66921679283', 'mean = 0.00552239701377')
# ('layer0', 'var = 0.660711236139', 'mean = 0.0129634627606')
# ('layer0', 'var = 0.645085860613', 'mean = 0.0117394707767')
# ('layer0', 'var = 0.769747613097', 'mean = 0.00299637029992')
# ('layer0', 'var = 0.797490343455', 'mean = 0.0274918882859')
# ('layer0', 'var = 0.816888091325', 'mean = -0.0253869896236')
# ('layer0', 'var = 0.858270174732', 'mean = 0.00506000832443')
# ('layer0', 'var = 0.907337711606', 'mean = -0.0334674253305')
# ('layer0', 'var = 0.882732985759', 'mean = 0.0410164865446')
# ('layer0', 'var = 0.901381963255', 'mean = -0.0172678957274')
# ('layer0', 'var = 0.903057843211', 'mean = 0.0167453641855')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
#             batch_size=20, n_hidden=30, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save9
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.226753742111', 'mean = -0.0290920849321')
# ('layer0', 'var = 0.431585219343', 'mean = 0.0105721797178')
# ('layer0', 'var = 0.564945677642', 'mean = -0.0377354800609')
# ('layer0', 'var = 0.652473916351', 'mean = -0.0349648866196')
# ('layer0', 'var = 0.683189905033', 'mean = -0.027932952067')
# ('layer0', 'var = 0.645009209616', 'mean = -0.0446849780328')
# ('layer0', 'var = 0.759659643086', 'mean = -0.024930455714')
# ('layer0', 'var = 0.795176452697', 'mean = -0.0243648927968')
# ('layer0', 'var = 0.805918951638', 'mean = 0.0204950045369')
# ('layer0', 'var = 0.875226310152', 'mean = -0.00695152486593')
# ('layer0', 'var = 0.898399083894', 'mean = -0.0375924021911')
# ('layer0', 'var = 0.89786152571', 'mean = -0.0383108380106')
# ('layer0', 'var = 0.9107957569', 'mean = -0.0515213546196')
# ('layer0', 'var = 0.909107087665', 'mean = -0.0268898082178')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
#             batch_size=20, n_hidden=20, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save10
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.224827310277', 'mean = 0.0202438594892')
# ('layer0', 'var = 0.428105282384', 'mean = -0.012511617403')
# ('layer0', 'var = 0.569190462457', 'mean = 0.0337078038293')
# ('layer0', 'var = 0.670794444043', 'mean = -0.0114265940588')
# ('layer0', 'var = 0.648918762221', 'mean = -0.00457027073598')
# ('layer0', 'var = 0.68385699693', 'mean = 0.00884510236859')
# ('layer0', 'var = 0.769246267446', 'mean = 0.0069527594066')
# ('layer0', 'var = 0.806413057427', 'mean = -0.00129214994142')
# ('layer0', 'var = 0.836212697085', 'mean = 0.0174182764605')
# ('layer0', 'var = 0.879337398871', 'mean = 0.0136264961652')
# ('layer0', 'var = 0.91977665533', 'mean = -0.0158306085418')
# ('layer0', 'var = 0.896838684117', 'mean = -0.0500754980293')
# ('layer0', 'var = 0.910500143788', 'mean = -0.0313383987538')
# ('layer0', 'var = 0.868034712231', 'mean = -0.0650110429503')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,
#             batch_size=20, n_hidden=15, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save11
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.236633235473', 'mean = -0.050786604134')
# ('layer0', 'var = 0.428227192325', 'mean = -0.0907651531973')
# ('layer0', 'var = 0.529357740108', 'mean = -0.115360544039')
# ('layer0', 'var = 0.641048057184', 'mean = -0.101862968032')
# ('layer0', 'var = 0.661420068611', 'mean = -0.155812525828')
# ('layer0', 'var = 0.614406309143', 'mean = -0.227260723298')
# ('layer0', 'var = 0.769282572746', 'mean = -0.192504403229')
# ('layer0', 'var = 0.801767985772', 'mean = -0.189058929476')
# ('layer0', 'var = 0.771337605942', 'mean = -0.188102430174')
# ('layer0', 'var = 0.887570983212', 'mean = -0.136670681257')
# ('layer0', 'var = 0.903932631808', 'mean = -0.0818347306701')
# ('layer0', 'var = 0.891542463039', 'mean = -0.0652314621652')
# ('layer0', 'var = 0.922390411731', 'mean = -0.0379826337391')
# ('layer0', 'var = 0.877877533608', 'mean = -0.148942857695')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.00005, n_epochs=150,
#             batch_size=20, n_hidden=20, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save12
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.23180507953', 'mean = -0.0407859845668')
# ('layer0', 'var = 0.421275076988', 'mean = 0.00562497497468')
# ('layer0', 'var = 0.556615674248', 'mean = -0.0492912224597')
# ('layer0', 'var = 0.669488822988', 'mean = -0.0109571989617')
# ('layer0', 'var = 0.658672270871', 'mean = -0.0686823534545')
# ('layer0', 'var = 0.667124974523', 'mean = -0.0530148258955')
# ('layer0', 'var = 0.75829768011', 'mean = -0.0441692990193')
# ('layer0', 'var = 0.799603908736', 'mean = -0.055149262504')
# ('layer0', 'var = 0.808198980599', 'mean = -0.0842377743768')
# ('layer0', 'var = 0.881790213348', 'mean = -0.0538422392008')
# ('layer0', 'var = 0.900028680858', 'mean = 0.0167254946467')
# ('layer0', 'var = 0.897007501554', 'mean = -0.0281383423179')
# ('layer0', 'var = 0.920472083921', 'mean = -0.0590663813629')
# ('layer0', 'var = 0.904415135395', 'mean = -0.0592986720392')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.00003, n_epochs=150,
#             batch_size=20, n_hidden=20, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save13
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.223245771013', 'mean = 0.0205450093426')
# ('layer0', 'var = 0.447494741513', 'mean = -0.0100697046989')
# ('layer0', 'var = 0.547830025621', 'mean = 0.00961951688142')
# ('layer0', 'var = 0.641813244758', 'mean = 0.0256482367241')
# ('layer0', 'var = 0.671502341186', 'mean = -0.0099051336538')
# ('layer0', 'var = 0.651817203769', 'mean = 0.00830008763039')
# ('layer0', 'var = 0.762981141291', 'mean = 0.00167642206996')
# ('layer0', 'var = 0.83776186553', 'mean = -0.0302291672417')
# ('layer0', 'var = 0.802104398999', 'mean = 0.00182769492247')
# ('layer0', 'var = 0.873364833357', 'mean = -0.00597874326125')
# ('layer0', 'var = 0.927756419919', 'mean = -0.00195642333282')
# ('layer0', 'var = 0.894330955826', 'mean = 0.0722076196727')
# ('layer0', 'var = 0.917880677873', 'mean = -0.00549196137331')
# ('layer0', 'var = 0.899461665095', 'mean = 0.0047182369789')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0000, n_epochs=150,
#             batch_size=20, n_hidden=20, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save14
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.237189379386', 'mean = -0.0503289544017')
# ('layer0', 'var = 0.420773469266', 'mean = 0.0059038125814')
# ('layer0', 'var = 0.543456777023', 'mean = -0.0332284179538')
# ('layer0', 'var = 0.653746518525', 'mean = -0.0569469530778')
# ('layer0', 'var = 0.635243573864', 'mean = -0.0264284305834')
# ('layer0', 'var = 0.643959169555', 'mean = -0.0972292733329')
# ('layer0', 'var = 0.772737487574', 'mean = -0.0345610394884')
# ('layer0', 'var = 0.831915390078', 'mean = -0.0269335512917')
# ('layer0', 'var = 0.813114138999', 'mean = -0.0814975899134')
# ('layer0', 'var = 0.887348310031', 'mean = -0.0220621087087')
# ('layer0', 'var = 0.919006024372', 'mean = -0.0597656867652')
# ('layer0', 'var = 0.899842099051', 'mean = -0.029958410292')
# ('layer0', 'var = 0.918579135769', 'mean = 0.0513650052862')
# ('layer0', 'var = 0.90971587441', 'mean = 0.0141712899669')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0002, n_epochs=150,
#             batch_size=20, n_hidden=20, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save15
# Out:
# start
# Training batches: 92689
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.228763072727', 'mean = 0.0187489249528')
# ('layer0', 'var = 0.432427265852', 'mean = 0.0808591436127')
# ('layer0', 'var = 0.555986883385', 'mean = 0.0559005224305')
# ('layer0', 'var = 0.657403426264', 'mean = 0.0573723626729')
# ('layer0', 'var = 0.668480444462', 'mean = 0.0398906821559')
# ('layer0', 'var = 0.676188857517', 'mean = 0.0279185521463')
# ('layer0', 'var = 0.764629347702', 'mean = 0.0570429647807')
# ('layer0', 'var = 0.814783311026', 'mean = 0.055026304164')
# ('layer0', 'var = 0.805318603479', 'mean = 0.000247374112863')
# ('layer0', 'var = 0.88218766943', 'mean = 0.0306334982222')
# ('layer0', 'var = 0.896799656611', 'mean = 0.0497232776374')
# ('layer0', 'var = 0.888874504177', 'mean = 0.0411071667446')
# ('layer0', 'var = 0.911601206484', 'mean = 0.0713213814579')
# ('layer0', 'var = 0.893827951532', 'mean = -0.00464393998495')
# ...

# %%
#learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,
#             batch_size=20, n_hidden=15, n_hiddenLayers=4
# %run dnn_1minClassification.py
#save11-2
# Out:
# start
# Training batches: 123586
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 0.221183502084', 'mean = -0.000335446189183')
# ('layer0', 'var = 0.439770520944', 'mean = -0.0467070226624')
# ('layer0', 'var = 0.558273828055', 'mean = -0.0621220298535')
# ('layer0', 'var = 0.6496951282', 'mean = -0.00372509180672')
# ('layer0', 'var = 0.702394367965', 'mean = -0.0659037249845')
# ('layer0', 'var = 0.740705917326', 'mean = -0.0287632814072')
# ('layer0', 'var = 0.701194139676', 'mean = 0.00856339630791')
# ('layer0', 'var = 0.728492437873', 'mean = -0.0425072204739')
# ('layer0', 'var = 0.80685564958', 'mean = 0.0392000807486')
# ('layer0', 'var = 0.86886116531', 'mean = -0.0367813721493')
# ('layer0', 'var = 0.846977314957', 'mean = -0.0647904474324')
# ('layer0', 'var = 0.854807171968', 'mean = -0.0416165256889')
# ('layer0', 'var = 0.888277320015', 'mean = -0.0308894385636')
# ('layer0', 'var = 0.910914715017', 'mean = -0.0350168892317')
# ...
