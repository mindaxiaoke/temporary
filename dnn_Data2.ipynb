# %%
# Using Train_X1:
#   signal(1:10) to predict spy(11)
# %run dnn_Data2

# Results:
# learning_rate=0.0001, L1_reg=0.00, L2_reg=0.0002, n_epochs=40,
#             batch_size=1, n_hidden=20, n_hiddenLayers=1, verbose=True,
# Accuracy: 53.91% on test set  (53% on training, 53.9% on validation set)
# Correlation: 0.1746
# Out:
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/myang/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_63_Stepping_2_GenuineIntel-2.7.11-64/tmph4n7ug/265abc51f7c376c224983485238ff1a5.lib and object C:/Users/myang/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_63_Stepping_2_GenuineIntel-2.7.11-64/tmph4n7ug/265abc51f7c376c224983485238ff1a5.exp
#
# Using gpu device 0: NVS 510 (CNMeM is enabled with initial size: 95.0% of memory, cuDNN 5004)
# start
# Training batches: 400
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 1.01693451261e-05', 'mean = -0.00262650689214')
# ('layer0', 'var = 0.489084124835', 'mean = -0.0105822108768')
# ... training
# epoch 1, minibatch 400/400, validation error 7.772225 %
#      epoch 1, minibatch 400/400, test error of best model 5.473682 %
# epoch 2, minibatch 400/400, validation error 7.750224 %
# ...

# %%
# Using Train_X1:
#   signal(1:10) to predict spy(11)
# %run dnn_Data2

# Results:
#learning_rate=0.0001, L1_reg=0.00, L2_reg=0.0002, n_epochs=50,
#             batch_size=1, n_hidden=20, n_hiddenLayers=1, verbose=True
# Accuracy: 53.13% on test set  (53.75% on training, 57.03% on validation set)
# Correlation: 0.0047
# Out:
# start
# Training batches: 400
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 1.53417885675e-05', 'mean = -0.00131364702875')
# ('layer0', 'var = 0.363719211656', 'mean = -0.261041307086')
# ... training
# epoch 1, minibatch 400/400, validation error 7.772225 %
#      epoch 1, minibatch 400/400, test error of best model 5.473682 %
# epoch 2, minibatch 400/400, validation error 7.750224 %
#      epoch 2, minibatch 400/400, test error of best model 5.460498 %
# epoch 3, minibatch 400/400, validation error 7.734621 %
#      epoch 3, minibatch 400/400, test error of best model 5.451987 %
# epoch 4, minibatch 400/400, validation error 7.723423 %
#      epoch 4, minibatch 400/400, test error of best model 5.446495 %
# epoch 5, minibatch 400/400, validation error 7.715287 %
#      epoch 5, minibatch 400/400, test error of best model 5.442953 %
# epoch 6, minibatch 400/400, validation error 7.709306 %
# ...

# %%
# Using Train_X1:
#   signal(1:10) to predict spy(11)
# %run dnn_Data2

# Results:
#learning_rate=0.0001, L1_reg=0.00, L2_reg=0.001, n_epochs=120,
#             batch_size=1, n_hidden=20, n_hiddenLayers=1, verbose=True,
# Accuracy: 53.91% on test set  (61% on training, 53.13% on validation set)
# Correlation: 0.0154
# Out:
# start
# Training batches: 400
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 1.46890619929e-05', 'mean = -0.00154234119497')
# ('layer0', 'var = 0.358505223672', 'mean = -0.000560694031756')
# ... training
# epoch 1, minibatch 400/400, validation error 7.772242 %
#      epoch 1, minibatch 400/400, test error of best model 5.473691 %
# epoch 2, minibatch 400/400, validation error 7.750258 %
#      epoch 2, minibatch 400/400, test error of best model 5.460516 %
# epoch 3, minibatch 400/400, validation error 7.734673 %
#      epoch 3, minibatch 400/400, test error of best model 5.452014 %
# epoch 4, minibatch 400/400, validation error 7.723491 %
#      epoch 4, minibatch 400/400, test error of best model 5.446530 %
# epoch 5, minibatch 400/400, validation error 7.715372 %
#      epoch 5, minibatch 400/400, test error of best model 5.442996 %
# epoch 6, minibatch 400/400, validation error 7.709406 %
# ...

# %%
# Using Train_X3:
#   signal(1:10) and spy(1:10) to predict spy(11)
# %run dnn_Data2

# Results:
# learning_rate=0.01, L1_reg=0.00, L2_reg=0.01, n_epochs=30,
#             batch_size=1, n_hidden=20, n_hiddenLayers=1, verbose=True
# Accuracy: 55.47% on test set  (59.75% on training, 57.03% on validation set)
# Correlation: 0.0839
# Out:
# start
# Training batches: 400
# ... building the model
# ('layer0', 'SVD Decompostion done.')
# ('layer0', 'var = 2.79782506824e-05', 'mean = -0.00156964786597')
# ('layer0', 'var = 0.408001453892', 'mean = 0.108878520345')
# ... training
# epoch 1, minibatch 400/400, validation error 8.151852 %
#      epoch 1, minibatch 400/400, test error of best model 5.672345 %
# epoch 2, minibatch 400/400, validation error 8.113745 %
#      epoch 2, minibatch 400/400, test error of best model 5.651082 %
# epoch 3, minibatch 400/400, validation error 8.080394 %
#      epoch 3, minibatch 400/400, test error of best model 5.632312 %
# epoch 4, minibatch 400/400, validation error 8.051789 %
#      epoch 4, minibatch 400/400, test error of best model 5.616236 %
# epoch 5, minibatch 400/400, validation error 8.027578 %
#      epoch 5, minibatch 400/400, test error of best model 5.602737 %
# epoch 6, minibatch 400/400, validation error 8.007272 %
# ...
